# %%
# from google.colab import drive
# import os

# # drive.mount('/content/gdrive')
# os.chdir('./gdrive/MyDrive/Project')

# %%
ls
# Out:
# architecture.py  first.ipynb  model2/        __pycache__/
# Dataset/         model1/      predict.ipynb  utils.py

# %%
import os
import torch
import torchvision
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from torchsummary import summary
# !pip install torchviz
from architecture import Architecture
from utils import train, plot
import pickle as pkl
import shutil

torch.manual_seed(0)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: torchviz in /home/sartazz7/.local/lib/python3.10/site-packages (0.0.2)
# Requirement already satisfied: torch in /home/sartazz7/.local/lib/python3.10/site-packages (from torchviz) (1.12.1+cpu)
# Requirement already satisfied: graphviz in /home/sartazz7/.local/lib/python3.10/site-packages (from torchviz) (0.20.1)
# Requirement already satisfied: typing-extensions in /home/sartazz7/.local/lib/python3.10/site-packages (from torch->torchviz) (4.3.0)

# %%
min_images = 20
max_images = 200
image_shape = (64, 64)
num_channels = 1

transform = torchvision.transforms.Compose([
    torchvision.io.read_image,
    torchvision.transforms.functional.rgb_to_grayscale,
    torchvision.transforms.Resize(size = image_shape),
])

# transform = torchvision.transforms.Compose([
#     torchvision.io.read_image,
#     torchvision.transforms.Resize(size = image_shape),
# ])

# %%
dataset = './Dataset/lfw_funneled/'
names = []
for name in os.listdir(dataset):
    if len(os.listdir(dataset+name)) >= min_images:
        names.append(name)

train_images, val_images, train_labels, val_labels = [], [], [], []

for i,name in enumerate(names):
    imgs = [dataset+name+'/'+img for img in os.listdir(dataset+name)]
    imgs = [imgs[i] for i in torch.randperm(len(imgs))[:max_images]]
    lbls = [i for img in imgs]
    imgs1, imgs2, lbls1, lbls2 = train_test_split(imgs, lbls, random_state=42, test_size=0.2)
    train_images += imgs1
    val_images += imgs2
    train_labels += lbls1
    val_labels += lbls2

print(f'Train Data size : {len(train_images)}\nValidation Data size : {len(val_images)}')
# Out:
# Train Data size : 1134
# Validation Data size : 294

# %%
modelname = 'model2'
if os.path.exists(f'./{modelname}/'):
  shutil.rmtree(f'./{modelname}')
os.mkdir(f'./{modelname}')

pkl.dump(names, open(f'./{modelname}/names.pkl', 'wb'))

# %%
class MyDataset(torch.utils.data.Dataset):
    def __init__(self, img_paths, labels, transform):
        super().__init__()
        self.img_paths = img_paths
        self.labels = labels
        self.transform = transform

    def __len__(self):
        return len(self.img_paths)

    def __getitem__(self, idx):
        image = self.transform(self.img_paths[idx])
        label = torch.zeros(len(names))
        label[self.labels[idx]] = 1
        return (image, label)

# %%
train_ds = MyDataset(train_images, train_labels, transform)
val_ds = MyDataset(val_images, val_labels, transform)

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

arct_args = {
    'image_shape': (2, num_channels, *image_shape),
    'in_ch1': num_channels,
    'out_ch1': 64,
    'in_ch2': 256,
    'out_ch2': len(names),
    'layer1': 2,
    'layer2': 1,
    'layer3': 1,
    'arct_name': modelname
}

arct = Architecture(arct_args).to(device)
print(summary(arct, (num_channels, *image_shape)))
print(device)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 62, 62]             640
#               ReLU-2           [-1, 64, 62, 62]               0
#        BatchNorm2d-3           [-1, 64, 62, 62]             128
#             Conv2d-4           [-1, 64, 60, 60]          36,928
#               ReLU-5           [-1, 64, 60, 60]               0
#        BatchNorm2d-6           [-1, 64, 60, 60]             128
#             Conv2d-7           [-1, 64, 60, 60]          36,928
#               ReLU-8           [-1, 64, 60, 60]               0
#        BatchNorm2d-9           [-1, 64, 60, 60]             128
#         MaxPool2d-10           [-1, 64, 30, 30]               0
#           Dropout-11           [-1, 64, 30, 30]               0
#            Layer1-12           [-1, 64, 30, 30]               0
#            Conv2d-13          [-1, 128, 28, 28]          73,856
#              ReLU-14          [-1, 128, 28, 28]               0
#       BatchNorm2d-15          [-1, 128, 28, 28]             256
#            Conv2d-16          [-1, 128, 26, 26]         147,584
#              ReLU-17          [-1, 128, 26, 26]               0
#       BatchNorm2d-18          [-1, 128, 26, 26]             256
#            Conv2d-19          [-1, 128, 26, 26]         147,584
#              ReLU-20          [-1, 128, 26, 26]               0
#       BatchNorm2d-21          [-1, 128, 26, 26]             256
#         MaxPool2d-22          [-1, 128, 13, 13]               0
#           Dropout-23          [-1, 128, 13, 13]               0
#            Layer1-24          [-1, 128, 13, 13]               0
#            Conv2d-25          [-1, 256, 11, 11]         295,168
#              ReLU-26          [-1, 256, 11, 11]               0
#       BatchNorm2d-27          [-1, 256, 11, 11]             512
#         MaxPool2d-28            [-1, 256, 5, 5]               0
#           Dropout-29            [-1, 256, 5, 5]               0
#            Layer2-30            [-1, 256, 5, 5]               0
#           Flatten-31                 [-1, 6400]               0
#            Linear-32                  [-1, 256]       1,638,656
#       BatchNorm1d-33                  [-1, 256]             512
#            Layer3-34                  [-1, 256]               0
#            Linear-35                   [-1, 23]           5,911
#           Softmax-36                   [-1, 23]               0
# ================================================================
# Total params: 2,385,431
# Trainable params: 2,385,431
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.02
# Forward/backward pass size (MB): 25.16
# Params size (MB): 9.10
# Estimated Total Size (MB): 34.27
# ----------------------------------------------------------------
# None
# cuda

# %%
train_args = {
    'epochs': 50,
    'batch_size': 16,
    'learning_rate': 0.001,
    'momentum': 0.4,
    'device': device,
    'save': True,
    'output': True,
    'arct_name': modelname,
    'weight_decay': 0.01
}

H = train(arct, train_ds, val_ds, train_args)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# EPOCH: 1/50
# Train loss: 3.1240, Val loss: 3.1371,
# Train Accuracy: 0.0707, Val Accuracy: 0.07483
# EPOCH: 2/50
# Train loss: 3.0489, Val loss: 3.0329,
# Train Accuracy: 0.1661, Val Accuracy: 0.1667
# EPOCH: 3/50
# Train loss: 3.0089, Val loss: 3.0036,
# Train Accuracy: 0.2076, Val Accuracy: 0.2075
# EPOCH: 4/50
# Train loss: 2.9457, Val loss: 2.9770,
# Train Accuracy: 0.2641, Val Accuracy: 0.2381
# EPOCH: 5/50
# Train loss: 2.8810, Val loss: 2.8770,
# Train Accuracy: 0.3357, Val Accuracy: 0.3401
# EPOCH: 6/50
# Train loss: 2.7480, Val loss: 2.7792,
# Train Accuracy: 0.4691, Val Accuracy: 0.4286
# EPOCH: 7/50
